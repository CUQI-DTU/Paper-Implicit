# %% [markdown]
# # Source term recovery in 1D Poisson equation

# %%
# %%
import numpy as np
import matplotlib.pyplot as plt
from utils import Poisson
import cuqi

# %%
print("CUQI version:", cuqi.__version__)
# Out:
# CUQI version: 1.5.0

# %%
from cuqi.distribution import Gaussian, Gamma, JointDistribution
from cuqi.implicitprior import RegularizedGMRF
from cuqi.sampler import LinearRTO, RegularizedLinearRTO, HybridGibbs, Conjugate, LinearRTO

# %%
import matplotlib 

fontsize = 20
legendfontsize = 20

matplotlib.rc('xtick', labelsize=fontsize) 
matplotlib.rc('ytick', labelsize=fontsize)

# %% [markdown]
# ## Prepare forward model and synthetic data

# %%
np.random.seed(0)

# %%
nx = 128
poisson = Poisson(nx)

signal_index = 1

if signal_index == 1:
    xx = np.linspace(0, 1, 128+1)
    x_exact = np.sin(4*np.pi*xx)
    x_exact[np.where(x_exact < 0)]=0
else:
    x_exact = np.zeros(nx+1)

    x_exact[25:35] = 0.5

    x_exact[45:60] = 1

    x_exact[80:95] = 0.8

plt.figure()
plt.plot(np.linspace(0,1,129), x_exact, label='f', color="k")
plt.legend(fontsize=legendfontsize, loc="upper right")

# %%
y_exact = poisson.forward(x_exact)

noise_scale = 1e-3#3e-4#1e-3#3e-3
noise = noise_scale*np.random.randn(y_exact.size)
y_data = y_exact + noise
# %%
plt.figure()
plt.plot(np.linspace(0,1,129), y_exact, label="$u_{exact}$", color="k")
plt.scatter(np.linspace(0,1,129), y_data, s=80, facecolors='none', edgecolors='C0', label="$y_{obs}$")
plt.legend(fontsize=legendfontsize, loc="lower center")
plt.ylim([0,0.05])
plt.xlim([0, 1])
plt.xticks([0, 0.25, 0.5, 0.75, 1], ['0', '0.25', '0.5', '0.75', '1'])
plt.savefig("rhs_data_sigma_1.pdf", bbox_inches='tight')

# %%
model_func = cuqi.model.LinearModel(poisson.forward, adjoint=poisson.adjoint, range_geometry=nx+1, domain_geometry=nx+1)

# %% [markdown]
# ## GMRF with nonnegativity

# %%
# Regularized GMRF with Gibbs (to learn precision as well)
np.random.seed(0)
d = Gamma(1, 1e-4)
x = RegularizedGMRF(np.zeros(nx+1), prec = lambda d:d, constraint = "nonnegativity")
measure_variance = np.ones(nx+1)*noise_scale**2
y  = Gaussian(model_func(x), measure_variance)

# Combine into a joint distribution
joint = JointDistribution(d, x, y)
posterior = joint(y=y_data)

sampling_strategy = {
    'x': RegularizedLinearRTO(maxit=50),
    'd': Conjugate()
}

sampler_rgmrf_gibbs = HybridGibbs(posterior, sampling_strategy)
sampler_rgmrf_gibbs.warmup(200)
sampler_rgmrf_gibbs.sample(10000)

samples_rgmrf_gibbs = sampler_rgmrf_gibbs.get_samples().burnthin(200)
# Out:
# Warmup: 100%|██████████| 200/200 [00:28<00:00,  7.08it/s]
# Sample: 100%|██████████| 10000/10000 [21:30<00:00,  7.75it/s]

# %%
samples_rgmrf_gibbs['x'].geometry.grid = np.linspace(0,1,129)

# %%
samples_rgmrf_gibbs['d'].plot_trace()
plt.figure()
samples_rgmrf_gibbs['x'].plot_ci(exact=x_exact)
plt.vlines([0.25, 0.5, 0.75], -3, 3, linestyles=':', colors='gray')
plt.xlim([0, 1])
plt.ylim([-1, 2])
plt.xticks([0, 0.25, 0.5, 0.75, 1], ['0', '0.25', '0.5', '0.75', '1'])
plt.legend(['95% CI', 'Mean', 'True'], fontsize=fontsize, loc="upper right")
plt.savefig("rhs_regularized_gmrf_gibbs_sigma_1.pdf", bbox_inches='tight')

# %% [markdown]
# # GMRF (reference)

# %%
# GMRF with Gibbs (to learn precision as well)
np.random.seed(1)
d = Gamma(1, 1e-4)
x = cuqi.distribution.GMRF(np.zeros(nx+1), prec = lambda d:d)
measure_variance = np.ones(nx+1)*noise_scale**2
y  = Gaussian(model_func(x), measure_variance)

# Combine into a joint distribution
joint = JointDistribution(d, x, y)
posterior = joint(y=y_data)

sampling_strategy = {
    'x': LinearRTO(maxit=50),
    'd': Conjugate()
}

sampler_gmrf_gibbs = HybridGibbs(posterior, sampling_strategy)
sampler_gmrf_gibbs.warmup(200)
sampler_gmrf_gibbs.sample(10000)
samples_gmrf_gibbs = sampler_gmrf_gibbs.get_samples().burnthin(200, 10)
# Out:
# Warmup: 100%|██████████| 200/200 [00:12<00:00, 15.56it/s]
# Sample: 100%|██████████| 10000/10000 [11:22<00:00, 14.64it/s]

# %%
samples_gmrf_gibbs['x'].geometry.grid = np.linspace(0,1,129)

# %%
samples_gmrf_gibbs['d'].plot_trace()
plt.figure()
samples_gmrf_gibbs['x'].plot_ci(exact=x_exact)
plt.vlines([0.25, 0.5, 0.75], -3, 3, linestyles=':', colors='gray')
plt.xlim([0, 1])
plt.ylim([-1, 2])
plt.xticks([0, 0.25, 0.5, 0.75, 1], ['0', '0.25', '0.5', '0.75', '1'])
plt.legend(['95% CI', 'Mean', 'True'], fontsize=fontsize, loc="upper right")
plt.savefig("rhs_gmrf_gibbs_sigma_1.pdf", bbox_inches='tight')

# %%
np.save("samples_rgmrf_gibbs_x_1.npy", samples_rgmrf_gibbs['x'].samples)
np.save("samples_gmrf_gibbs_x_1.npy", samples_gmrf_gibbs['x'].samples)

# %% [markdown]
# # Difference

# %%
import dolfin as df

sol_exact = df.Function(poisson.V)
sol_exact.vector()[:] = x_exact

sol_constrained = df.Function(poisson.V)
sol_constrained.vector()[:] = samples_rgmrf_gibbs['x'].mean()
diff_constrained = np.sqrt(df.assemble((sol_exact-sol_constrained)**2*df.dx))
print("L2 error of constrained GMRF:", diff_constrained)

sol_unconstrained = df.Function(poisson.V)
sol_unconstrained.vector()[:] = samples_gmrf_gibbs['x'].mean()
diff_unconstrained = np.sqrt(df.assemble((sol_exact-sol_unconstrained)**2*df.dx))
print("L2 error of unconstrained GMRF:", diff_unconstrained)
# Out:
# L2 error of constrained GMRF: 0.07882293114430594
# L2 error of unconstrained GMRF: 0.09599377090346844

# %%
print("95% CI width of RGMRF samples: ", samples_rgmrf_gibbs['x'].ci_width().mean())
print("95% CI width of GMRF samples: ", samples_gmrf_gibbs['x'].ci_width().mean())
# Out:
# 95% CI width of RGMRF samples:  0.16949994611315936
# 95% CI width of GMRF samples:  0.8439271012012254

# %%
print("Standard deviation of RGMRF samples: ", samples_rgmrf_gibbs['x'].std().mean())
print("Standard deviation of GMRF samples: ", samples_gmrf_gibbs['x'].std().mean())
# Out:
# Standard deviation of RGMRF samples:  0.04566942922490877
# Standard deviation of GMRF samples:  0.21286820804854642
